# %%
import pandas as pd

# %%
data = pd.read_csv('Hurricane-Data.csv')

# %%
data.plot.scatter(x='year', y = 'hc_occur')

# %%
data.corr()

# %%
from sklearn.linear_model import LinearRegression

# %%
lin = LinearRegression()
lin.fit(data[['year']], data['hc_occur'])
# Out:
# LinearRegression()

# %%
ax = data.plot.line(x='year', y ='hc_occur', alpha=.1 , c = 'black')
ax.plot(data['year'], lin.predict(data[['year']]), c='r')

# %%
from sklearn.metrics import r2_score

# %%
r2_score(data['hc_occur'], lin.predict(data[['year']]))
# Out:
# 0.23819805797858096

# %%
lin.score(data[['year']], data['hc_occur'])
# Out:
# <bound method RegressorMixin.score of LinearRegression()>
